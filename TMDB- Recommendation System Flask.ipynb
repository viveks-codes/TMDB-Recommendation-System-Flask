# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
from nltk import *

# %%
ls
# Out:
#  app.py          sim.pkl      tmdb_5000_credits.csv
#  finalPrep.csv   static/      tmdb_5000_movies.csv
#  movielist.pkl   templates/  'TMDB- Recommendation System Flask.ipynb'

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movies.isna().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
movies.shape
# Out:
# (4803, 20)

# %%
movies.isna().sum().sum()
# Out:
# 3941

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
credits.columns
# Out:
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
credits.shape
# Out:
# (4803, 4)

# %%
credits.isna().sum()
# Out:
# movie_id    0
# title       0
# cast        0
# crew        0
# dtype: int64

# %%
movies = movies.merge(credits,on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies['original_language'].value_counts()
# Out:
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 901.7+ KB

# %%
# id genres keywords title overview production_companies cast crew

# %%
movies = movies[["id","genres","keywords","title","overview","production_companies","cast","crew"]]

# %%
movies.head()
# Out:
#        id                                             genres  \
# 0   19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     285  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   49026  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   49529  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#id title tags

# %%
movies.isnull().sum()
# Out:
# id                      0
# genres                  0
# keywords                0
# title                   0
# overview                3
# production_companies    0
# cast                    0
# crew                    0
# dtype: int64

# %%
movies.dropna(inplace=True)
movies.isnull().sum()
# Out:
# id                      0
# genres                  0
# keywords                0
# title                   0
# overview                0
# production_companies    0
# cast                    0
# crew                    0
# dtype: int64

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def ConvertAllTuples(obj):
    L = []
    for i in ast.literal_eval(obj):
            L.append(i['name'])
    return L

# %%
def convertOnly3(obj):
    L = []
    counter = 0 
    for i in ast.literal_eval(obj):
        if counter !=3:
            L.append(i['name'])
            counter+=1
        break
    return L

# %%
movies.iloc[0].crew
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"}, {"credit_id": "52fe48009251416c750ac9d9", "department": "Writing", "gender": 2, "id": 2710, "job": "Writer", "name": "James Cameron"}, {"credit_id": "52fe48009251416c750aca17", "department": "Editing", "gender": 2, "id": 2710, "job": "Editor", "name": "James Cameron"}, {"credit_id": "52fe48009251416c750aca29", "department": "Production", "gender": 2, "id": 2710, "job": "Producer", "name": "James Cameron"}, {"credit_id": "52fe48009251416c750aca3f", "department": "Writing", "gender": 2, "id": 2710, "job": "Screenplay", "name": "James Cameron"}, {"credit_id": "539c4987c3a36810ba0021a4", "department": "Art", "gender": 2, "id": 7236, "job": "Art Direction", "name": "Andrew Menzies"}, {"credit_id": "549598c3c3a3686ae9004383", "department": "Visual Effects", "gender": 0, "id": 6690, "job": "Visual Effects Producer", "name": "Jill Brooks"}, {"credit_id": "52fe48009251416c750aca4b", "department": "Production", "gender": 1, "id": 6347, "job": "Casting", "name": "Margery Simkin"}, {"credit_id": "570b6f419251417da70032fe", "department": "Art", "gender": 2, "id": 6878, "job": "Supervising Art Director", "name": "Kevin Ishioka"}, {"credit_id": "5495a0fac3a3686ae9004468", "department": "Sound", "gender": 0, "id": 6883, "job": "Music Editor", "name": "Dick Bernstein"}, {"credit_id": "54959706c3a3686af3003e81", "department": "Sound", "gender": 0, "id": 8159, "job": "Sound Effects Editor", "name": "Shannon Mills"}, {"credit_id": "54491d58c3a3680fb1001ccb", "department": "Sound", "gender": 0, "id": 8160, "job": "Foley", "name": "Dennie Thorpe"}, {"credit_id": "54491d6cc3a3680fa5001b2c", "department": "Sound", "gender": 0, "id": 8163, "job": "Foley", "name": "Jana Vance"}, {"credit_id": "52fe48009251416c750aca57", "department": "Costume & Make-Up", "gender": 1, "id": 8527, "job": "Costume Design", "name": "Deborah Lynn Scott"}, {"credit_id": "52fe48009251416c750aca2f", "department": "Production", "gender": 2, "id": 8529, "job": "Producer", "name": "Jon Landau"}, {"credit_id": "539c4937c3a36810ba002194", "department": "Art", "gender": 0, "id": 9618, "job": "Art Direction", "name": "Sean Haworth"}, {"credit_id": "539c49b6c3a36810c10020e6", "department": "Art", "gender": 1, "id": 12653, "job": "Set Decoration", "name": "Kim Sinclair"}, {"credit_id": "570b6f2f9251413a0e00020d", "department": "Art", "gender": 1, "id": 12653, "job": "Supervising Art Director", "name": "Kim Sinclair"}, {"credit_id": "54491a6c0e0a26748c001b19", "department": "Art", "gender": 2, "id": 14350, "job": "Set Designer", "name": "Richard F. Mays"}, {"credit_id": "56928cf4c3a3684cff0025c4", "department": "Production", "gender": 1, "id": 20294, "job": "Executive Producer", "name": "Laeta Kalogridis"}, {"credit_id": "52fe48009251416c750aca51", "department": "Costume & Make-Up", "gender": 0, "id": 17675, "job": "Costume Design", "name": "Mayes C. Rubeo"}, {"credit_id": "52fe48009251416c750aca11", "department": "Camera", "gender": 2, "id": 18265, "job": "Director of Photography", "name": "Mauro Fiore"} ...

# %%
def convertOnlyDirectors(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
movies['genres'] = movies['genres'].apply(ConvertAllTuples)

# %%
movies['keywords'] = movies['keywords'].apply(ConvertAllTuples)

# %%
movies['production_companies'] = movies['production_companies'].apply(ConvertAllTuples)

# %%
movies['cast'] = movies['cast'].apply(convertOnly3)
movies['crew'] = movies['crew'].apply(convertOnlyDirectors)

# %%
movies.head()
# Out:
#        id                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                 production_companies               cast  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...  [Sam Worthington]
# 1  [Walt Disney Pictures, Jerry Bruckheimer Films...      [Johnny Depp]
# 2                   [Columbia Pictures, Danjaq, B24]     [Daniel Craig]
# 3  [Legendary Pictures, Warner Bros., DC Entertai...   [Christian Bale]
# 4                             [Walt Disney Pictures]    [Taylor Kitsch]
#
#                   crew
# 0      [James Cameron]
# 1     [Gore Verbinski]
# 2         [Sam Mendes]
# 3  [Christopher Nolan]
# 4     [Andrew Stanton]

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#        id                                         genres  \
# 0   19995  [Action, Adventure, Fantasy, Science Fiction]
# 1     285                   [Adventure, Fantasy, Action]
# 2  206647                     [Action, Adventure, Crime]
# 3   49026               [Action, Crime, Drama, Thriller]
# 4   49529           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                 production_companies               cast  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...  [Sam Worthington]
# 1  [Walt Disney Pictures, Jerry Bruckheimer Films...      [Johnny Depp]
# 2                   [Columbia Pictures, Danjaq, B24]     [Daniel Craig]
# 3  [Legendary Pictures, Warner Bros., DC Entertai...   [Christian Bale]
# 4                             [Walt Disney Pictures]    [Taylor Kitsch]
#
#                   crew
# 0      [James Cameron]
# 1     [Gore Verbinski]
# 2         [Sam Mendes]
# 3  [Christopher Nolan]
# 4     [Andrew Stanton]

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies['production_companies'] = movies['production_companies'].apply(collapse)

# %%
movies
# Out:
#           id                                        genres  \
# 0      19995  [Action, Adventure, Fantasy, ScienceFiction]
# 1        285                  [Adventure, Fantasy, Action]
# 2     206647                    [Action, Adventure, Crime]
# 3      49026              [Action, Crime, Drama, Thriller]
# 4      49529           [Action, Adventure, ScienceFiction]
# ...      ...                                           ...
# 4804    9367                     [Action, Crime, Thriller]
# 4805   72766                             [Comedy, Romance]
# 4806  231617             [Comedy, Drama, Romance, TVMovie]
# 4807  126186                                            []
# 4808   25975                                 [Documentary]
#
#                                                keywords  \
# 0     [cultureclash, future, spacewar, spacecolony, ...
# 1     [ocean, drugabuse, exoticisland, eastindiatrad...
# 2     [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3     [dccomics, crimefighter, terrorist, secretiden...
# 4     [basedonnovel, mars, medallion, spacetravel, p...
# ...                                                 ...
# 4804  [unitedstates–mexicobarrier, legs, arms, paper...
# 4805                                                 []
# 4806  [date, loveatfirstsight, narration, investigat...
# 4807                                                 []
# 4808           [obsession, camcorder, crush, dreamgirl]
#
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  \
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# 3     [Following, the, death, of, District, Attorney...
# 4     [John, Carter, is, a, war-weary,, former, mili...
# ...                                                 ...
# 4804  [El, Mariachi, just, wants, to, play, his, gui...
# 4805  [A, newlywed, couple's, honeymoon, is, upended...
# 4806  ["Signed,, Sealed,, Delivered", introduces, a,...
# 4807  [When, ambitious, New, York, attorney, Sam, is...
# 4808  [Ever, since, the, second, grade, when, he, fi...
#
#                                    production_companies              cast  \
# 0     [IngeniousFilmPartners, TwentiethCenturyFoxFil...  [SamWorthington]
# 1     [WaltDisneyPictures, JerryBruckheimerFilms, Se...      [JohnnyDepp]
# 2                       [ColumbiaPictures, Danjaq, B24]     [DanielCraig]
# 3     [LegendaryPictures, WarnerBros., DCEntertainme...   [ChristianBale]
# 4                                  [WaltDisneyPictures]    [TaylorKitsch]
# ...                                                 ...               ...
# 4804                                 [ColumbiaPictures]  [CarlosGallardo]
# 4805                                                 []     [EdwardBurns]
# 4806  [FrontStreetPictures, MuseEntertainmentEnterpr...      [EricMabius]
# 4807                                                 []    [DanielHenney]
# 4808           [rustybearentertainment, luckycrowfilms]   [DrewBarrymore]
#
#                     crew
# 0         [JamesCameron]
# 1        [GoreVerbinski]
# 2            [SamMendes]
# 3     [ChristopherNolan]
# 4        [AndrewStanton]
# ...                  ...
# 4804   [RobertRodriguez]
# 4805       [EdwardBurns]
# 4806        [ScottSmith]
# 4807        [DanielHsia]
# 4808   [BrianHerzlinger]
#
# [4806 rows x 8 columns]

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew'] + movies['production_companies']

# %%
df = movies.drop(columns=['overview','genres','keywords','cast','crew','production_companies'])

# %%
df['tags'] = df['tags'].apply(lambda x: " ".join(x))

# %%
df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
def stemm(strin):
    y = []
    for i in strin.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
ps = PorterStemmer()

# %%
df['tags'] = df['tags'].apply(stemm)

# %%
df.to_csv('finalPrep.csv')

# %%
df['tags'][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington jamescameron ingeniousfilmpartn twentiethcenturyfoxfilmcorpor duneentertain lightstormentertain'

# %%
df['tags'][1]
# Out:
# "captain barbossa, long believ to be dead, ha come back to life and is head to the edg of the earth with will turner and elizabeth swann. but noth is quit as it seems. adventur fantasi action ocean drugabus exoticisland eastindiatradingcompani loveofone'slif traitor shipwreck strongwoman ship allianc calypso afterlif fighter pirat swashbuckl aftercreditssting johnnydepp goreverbinski waltdisneypictur jerrybruckheimerfilm secondmateproduct"

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=8000,stop_words='english')

# %%
vector = cv.fit_transform(df['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# /home/vivek/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['000',
#  '007',
#  '10',
#  '100',
#  '10th',
#  '11',
#  '12',
#  '12th',
#  '13',
#  '14',
#  '1492pictur',
#  '15',
#  '150',
#  '15th',
#  '16',
#  '16th',
#  '17',
#  '17th',
#  '18',
#  '1863',
#  '1890',
#  '18th',
#  '18thcenturi',
#  '19',
#  '1910',
#  '1920',
#  '1927',
#  '1930',
#  '1930s',
#  '1937',
#  '1940',
#  '1940s',
#  '1941',
#  '1944',
#  '1945',
#  '1950',
#  '1950s',
#  '1955',
#  '1959',
#  '1960',
#  '1960s',
#  '1962',
#  '1964',
#  '1965',
#  '1967',
#  '1969',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1980s',
#  '1984',
#  '1984privatedefensecontractor',
#  '1985',
#  '1986',
#  '1987',
#  '1990',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1999',
#  '19th',
#  '19thcenturi',
#  '20',
#  '200',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2007',
#  '2008',
#  '2009',
#  '2011',
#  '2012',
#  '20th',
#  '21lapsentertain',
#  '21st',
#  '21stcenturi',
#  '22nd',
#  '23',
#  '24',
#  '25',
#  '27',
#  '28',
#  '29',
#  '2929product',
#  '30',
#  '300',
#  '35',
#  '3artsentertain',
#  '3d',
#  '40',
#  '400',
#  '40acres',
#  '47',
#  '50',
#  '500',
#  '51',
#  '5150action',
#  '60',
#  '60s',
#  '70',
#  '7th',
#  '80',
#  'a24',
#  'aardmananim',
#  'aaron',
#  'aaroneckhart',
#  'abandapart',
#  'abandon',
#  'abbi',
#  'abduct',
#  'abil',
#  'abl',
#  'aboard',
#  'aborigin',
#  'abort',
#  'abov',
#  'abram',
#  'abroad',
#  'absolut',
#  'absurd',
#  'abus',
#  'abuse',
#  'academ',
#  'academi',
#  'academy',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accompani',
#  'accomplish',
#  'account',
#  'accus',
#  'ace',
#  'achiev',
#  'acid',
#  'acquaint',
#  'acquir',
#  'act',
#  'action',
#  'actionhero',
#  'activ',
#  'activist',
#  'activities',
#  'actor',
#  'actress',
#  'actual',
#  'ad',
#  'ada',
#  'adam',
#  'adammckay',
#  'adams',
#  'adamsandl',
#  'adamshankman',
#  'adapt',
#  'add',
#  'addict',
#  'addiction',
#  'addit',
#  'addl',
#  'adjust',
#  'admir',
#  'admit',
#  'adolesc',
#  'adolf',
#  'adolfhitl',
#  'adopt',
#  'adoptivefath',
#  'ador',
#  'adrian',
#  'adrianlyn',
#  'adrienbrodi',
#  'adrift',
#  'adult',
#  'adultanim',
#  'adulteri',
#  'adulthood',
#  'adults',
#  'advanc',
#  'advantag',
#  'advantage',
#  'adventur',
#  'adventure',
#  'adventures',
#  'adversari',
#  'advertis',
#  'advic',
#  'advice',
#  'advis',
#  'affair',
#  'affc',
#  'affect',
#  'affection',
#  'affirmfilm',
#  'afflict',
#  'affluent',
#  'afford',
#  'afghanistan',
#  'afraid',
#  'africa',
#  'african',
#  'africanamerican',
#  'afro',
#  'aftercreditssting',
#  'afterdarkfilm',
#  'afterlif',
#  'aftermath',
#  'afternoon',
#  'ag',
#  'age',
#  'agediffer',
#  'agenc',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'aggress',
#  'aggressionbyanim',
#  'ago',
#  'agre',
#  'agrees',
#  'ahead',
#  'aid',
#  'aidan',
#  'ail',
#  'aim',
#  'air',
#  'airborn',
#  'aircraft',
#  'airforc',
#  'airplan',
#  'airplanecrash',
#  'airport',
#  'aka',
#  'al',
#  'alabama',
#  'alan',
#  'alaska',
#  'alaskan',
#  'albert',
#  'alcatraz',
#  'alcohol',
#  'alcoholabus',
#  'alconentertain',
#  'alecbaldwin',
#  'alejandrogonzáleziñárritu',
#  'alex',
#  'alexanderpayn',
#  'alexia',
#  'alexkendrick',
#  'alexproya',
#  'alfi',
#  'alfredhitchcock',
#  'algeria',
#  'ali',
#  'alic',
#  'alice',
#  'alien',
#  'alieninvas',
#  'alienlife',
#  'alienplanet',
#  'aliens',
#  'alik',
#  'alike',
#  'aliv',
#  'alive',
#  'alleg',
#  'allegedli',
#  'allen',
#  'alli',
#  'allianc',
#  'allianceatlantiscommun',
#  'alliancefilm',
#  'allies',
#  'allow',
#  'alon',
#  'alongsid',
#  'alp',
#  'alpacino',
#  'alpha',
#  'alphavillefilm',
#  'alreadi',
#  'alt',
#  'alter',
#  'altern',
#  'alternatehistori',
#  'alternater',
#  'alway',
#  'alyssa',
#  'alzheimer',
#  'amanda',
#  'amateur',
#  'amaz',
#  'amazon',
#  'ambassador',
#  'ambit',
#  'ambiti',
#  'amblinentertain',
#  'ambul',
#  'ambush',
#  'amenrafilm',
#  'america',
#  'american',
#  'americanabroad',
#  'americancivilwar',
#  'americandream',
#  'americanfootbal',
#  'americanfootballplay',
#  'americanzoetrop',
#  'ami',
#  'amid',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amsterdam',
#  'amulefilmwork',
#  'amus',
#  'amusementpark',
#  'amy',
#  'amyadam',
#  'amyheckerl',
#  'ana',
#  'anakin',
#  'analyst',
#  'anarchiccomedi',
#  'anarchist',
#  'anarchosproduct',
#  'ancient',
#  'ancientchina',
#  'ancientegypt',
#  'ancientgreec',
#  'ancientrom',
#  'ancientworld',
#  'anderson',
#  'andi',
#  'andrew',
#  'andrewadamson',
#  'andrewdavi',
#  'andrewflem',
#  'andrewniccol',
#  'andrewstanton',
#  'android',
#  'andrzejbartkowiak',
#  'andy',
#  'andyfickman',
#  'andygarcía',
#  'andytenn',
#  'angel',
#  'angela',
#  'angeles',
#  'angelinajoli',
#  'angels',
#  'anger',
#  'angle',
#  'angri',
#  'angst',
#  'ani',
#  'anim',
#  'animal',
#  'animalattack',
#  'animalhorror',
#  'animallog',
#  'animals',
#  'ann',
#  'anna',
#  'annabel',
#  'annafari',
#  'annakendrick',
#  'annapurnapictur',
#  'anne',
#  'annefletch',
#  'annehathaway',
#  'anni',
#  'annie',
#  'anniversari',
#  'announc',
#  'annoy',
#  'annual',
#  'anonym',
#  'anonymouscont',
#  'anoth',
#  'answer',
#  'answers',
#  'ant',
#  'antarct',
#  'antarctica',
#  'antholog',
#  'anthoni',
#  'anthonyhopkin',
#  'anthonyrusso',
#  'anthropomorph',
#  'anti',
#  'antic',
#  'anticip',
#  'antics',
#  'antihero',
#  'antiqu',
#  'antisemit',
#  'antiterror',
#  'antoinefuqua',
#  'anton',
#  'antoncapitalentertainment',
#  'antonio',
#  'antoniobandera',
#  'antonyelchin',
#  'anxieti',
#  'anyon',
#  'anyth',
#  'apart',
#  'apartheid',
#  'apartment',
#  'apatowproduct',
#  'ape',
#  'apes',
#  'apocalyps',
#  'apocalypse',
#  'apocalypt',
#  'apollo',
#  'apollomediadistribut',
#  'apostl',
#  'appalachia',
#  'appar',
#  'appear',
#  'appears',
#  'appianway',
#  'appl',
#  'apple',
#  'appli',
#  'appoint',
#  'appreci',
#  'apprehend',
#  'apprentic',
#  'approach',
#  'approaches',
#  'april',
#  'aquarium',
#  'arab',
#  'arabian',
#  'aramidentertainmentfund',
#  'arbitrarylaw',
#  'arch',
#  'archaeologist',
#  'archeolog',
#  'archer',
#  'archeri',
#  'architect',
#  'archiv',
#  'arctic',
#  'area',
#  'aren',
#  'arena',
#  'argument',
#  'aris',
#  'aristocrat',
#  'arizona',
#  'arm',
#  'armi',
#  'armor',
#  'armsdeal',
#  'army',
#  'arnold',
#  'arnoldschwarzenegg',
#  'arrang',
#  'arrangedmarriag',
#  'array',
#  'arrest',
#  'arrested',
#  'arriv',
#  'arrive',
#  'arrives',
#  'arrog',
#  'arson',
#  'art',
#  'artgalleri',
#  'arthur',
#  'articl',
#  'artifact',
#  'artifici',
#  'artificialintellig',
#  'artisanentertain',
#  'artist',
#  'artists',
#  'artlinsonproduct',
#  'artscouncilofengland',
#  'ash',
#  'ashley',
#  'ashtonkutch',
#  'asia',
#  'asian',
#  'asid',
#  'ask',
#  'aspect',
#  'aspir',
#  'assassin',
#  'assassins',
#  'assault',
#  'assembl',
#  'assign',
#  'assignment',
#  'assist',
#  'assistant',
#  'associ',
#  'assort',
#  'assum',
#  'asteroid',
#  'astralmedia',
#  'astronaut',
#  'asylum',
#  'atheist',
#  'athlet',
#  'atlant',
#  'atlanta',
#  'atlanticocean',
#  'atlasentertain',
#  'atmosphereentertainmentmm',
#  'atom',
#  'atomegoyan',
#  'atomicbomb',
#  'atroc',
#  'attach',
#  'attack',
#  'attacks',
#  'attempt',
#  'attemptedmurd',
#  'attempttoescap',
#  'attend',
#  'attent',
#  'attention',
#  'attic',
#  'attitud',
#  'attorney',
#  'attract',
#  'auction',
#  'audienc',
#  'audit',
#  'audrey',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'australianfilmfinancecorporation',
#  'australianoutback',
#  'austria',
#  'austrian',
#  'author',
#  'authorities',
#  'authority',
#  'autism',
#  'autist',
#  'auto',
#  'autobiograph',
#  'autobot',
#  'automatikentertain',
#  'automaton',
#  'automobilerac',
#  'autumn',
#  'avail',
#  'aveng',
#  'averag',
#  'avert',
#  'averypix',
#  'aviat',
#  'aviv',
#  'avoid',
#  'await',
#  'awak',
#  'awaken',
#  'awar',
#  'award',
#  'away',
#  'awe',
#  'awesom',
#  'awkward',
#  'awri',
#  'awry',
#  'ax',
#  'axe',
#  'axel',
#  'babe',
#  'babelsbergfilm',
#  'babi',
#  'baby',
#  'babysitt',
#  'bacfilm',
#  'bachelor',
#  'backdrop',
#  'background',
#  'backpack',
#  'backstag',
#  'backup',
#  'backward',
#  'backwat',
#  'backwood',
#  'backyard',
#  'bad',
#  'badboss',
#  'badhatharryproduct',
#  'badli',
#  'badluck',
#  'badmother',
#  'badrobot',
#  'bag',
#  'bahama',
#  'bahari',
#  'bail',
#  'baker',
#  'balanc',
#  'balance',
#  'balboa',
#  'baldwinentertainmentgroup',
#  'ball',
#  'ballet',
#  'balloon',
#  'baltimor',
#  'baltimorepictur',
#  'baltimorespringcreekproduct',
#  'ban',
#  'band',
#  'bandit',
#  'bandits',
#  'bangkok',
#  'banish',
#  'bank',
#  'banker',
#  'bankrobb',
#  'bankrobberi',
#  'bannon',
#  'bar',
#  'barbara',
#  'barbarian',
#  'barbershop',
#  'barbrastreisand',
#  'barcelonaspain',
#  'bare',
#  'bargain',
#  'barn',
#  'barney',
#  'baron',
#  'barri',
#  'barricad',
#  'barrier',
#  'barrio',
#  'barry',
#  'barrylevinson',
#  'barrymendelproduct',
#  'barrysonnenfeld',
#  'bars',
#  'bart',
#  'bas',
#  'base',
#  'basebal',
#  'baseball',
#  'basedonarticl',
#  'basedoncartoon',
#  'basedonchildren',
#  'basedoncomicbook',
#  'basedonfairytal',
#  'basedonfilm',
#  'basedongraphicnovel',
#  'basedonnovel',
#  'basedonplay',
#  'basedonshortstori',
#  'basedonstagemus',
#  'basedontrueev',
#  'basedontruestori',
#  'basedontvseri',
#  'basedonvideogam',
#  'basedonyoungadultnovel',
#  'basement',
#  'basket',
#  'basketbal',
#  'basketball',
#  'bat',
#  'bathroom',
#  'bathtub',
#  'batman',
#  'battalion',
#  'battl',
#  'battle',
#  'battleassign',
#  'battlefield',
#  'battleplanproduct',
#  'bavariafilm',
#  'baxter',
#  'bay',
#  'bazelevsproduct',
#  'bazluhrmann',
#  'bazmarkfilm',
#  'bbc',
#  'bbcfilm',
#  'bdsm',
#  'beach',
#  'beachhous',
#  'beaconcommun',
#  'beaconpictur',
#  'beam',
#  'bear',
#  'beard',
#  'beast',
#  'beasts',
#  'beat',
#  'beaten',
#  'beau',
#  'beauti',
#  'beautiful',
#  'beautifulwoman',
#  'beauty',
#  'becam',
#  'becaus',
#  'becca',
#  'becki',
#  'beckon',
#  'becom',
#  'becominganadult',
#  'bed',
#  'bedfordfallsproduct',
#  'bedroom',
#  'bee',
#  'beer',
#  'beethoven',
#  'befor',
#  'beforethedoorpictur',
#  'befriend',
#  'beg',
#  'began',
#  'beggar',
#  'begin',
#  'begins',
#  'beguil',
#  'behavior',
#  'behead',
#  'beijingnewpicturefilmco',
#  'belairentertain',
#  'belgium',
#  'belief',
#  'beliefs',
#  'believ',
#  'bell',
#  'bella',
#  'belong',
#  'belov',
#  'beloved',
#  'belt',
#  'ben',
#  'benaffleck',
#  'bend',
#  'benderspink',
#  'beneath',
#  'benefit',
#  'benjamin',
#  'benkingsley',
#  'bennet',
#  'bennett',
#  'benstil',
#  'bent',
#  'berlin',
#  'berni',
#  'best',
#  'bestfriend',
#  'bestfriendsinlov',
#  'bet',
#  'beth',
#  'bethani',
#  'betray',
#  'betrayal',
#  'betroth',
#  'bettemidl',
#  'better',
#  'betti',
#  'bettythoma',
#  'beverli',
#  'beverlyhil',
#  'bi',
#  'bia',
#  'bianca',
#  'bibl',
#  'biblic',
#  'bicker',
#  'bicycl',
#  'bid',
#  'big',
#  'bigbeachfilm',
#  'bigger',
#  'biggest',
#  'bigotri',
#  'bigscreenproduct',
#  'bigtalkproduct',
#  'bike',
#  'biker',
#  'bikini',
#  'bilbo',
#  'billcondon',
#  'billewoodruff',
#  'billi',
#  'billion',
#  'billionair',
#  'billmurray',
#  'billpaxton',
#  'billy',
#  'billybobthornton',
#  'billywild',
#  'bimdistribuzion',
#  'bind',
#  'binocular',
#  'bio',
#  'biograph',
#  'biographi',
#  'biolog',
#  'biologicalweapon',
#  'biologist',
#  'biopic',
#  'bird',
#  'birth',
#  'birthday',
#  'bisexu',
#  'bishop',
#  'bit',
#  'bite',
#  'bitten',
#  'bitter',
#  'bittersweet',
#  'bizarr',
#  'black',
#  'blackandwhit',
#  'blackhol',
#  'blackmag',
#  'blackmail',
#  'blackpeopl',
#  'blacksmith',
#  'blade',
#  'blake',
#  'blame',
#  'blart',
#  'blast',
#  'blaxploit',
#  'blaze',
#  'blend',
#  'bless',
#  'blind',
#  'blinddat',
#  'blindingedgepictur',
#  'blindnessandimpairedvis',
#  'bliss',
#  'blizzard',
#  'block',
#  'blofeld',
#  'blog',
#  'blond',
#  'blonde',
#  'blood',
#  'bloodi',
#  'bloodsplatt',
#  'bloodthirsti',
#  'bloom',
#  'blossom',
#  'blow',
#  'blu',
#  'blue',
#  'bluegrassfilm',
#  'blueskystudio',
#  'blumhouseproduct',
#  'blunt',
#  'blur',
#  'board',
#  'boardingschool',
#  'boat',
#  'bob',
#  'bobbi',
#  'bobby',
#  'bobbyfarrelli',
#  'bobyariproduct',
#  'bodi',
#  'body',
#  'bodyguard',
#  'bodyhorror',
#  'bohemian',
#  'bold',
#  'boldfilm',
#  'bollywood',
#  'bolt',
#  'bomb',
#  'bomber',
#  'bonafideproduct',
#  'bond',
#  'bone',
#  'boo',
#  'book',
#  'books',
#  'boot',
#  'border',
#  'bore',
#  'boredom',
#  'boring',
#  'born',
#  'borrow',
#  'boss',
#  'boston',
#  'botch',
#  'bottl',
#  'bounc',
#  'bound',
#  'boundari',
#  'bounti',
#  'bountyhunt',
#  'bourn',
#  'bout',
#  'bowl',
#  'box',
#  'boxer',
#  'boxingmatch',
#  'boy',
#  'boyd',
#  'boyfriend',
#  'boys',
#  'brad',
#  'bradanderson',
#  'bradbird',
#  'bradgreypictur',
#  'bradleycoop',
#  'bradpitt',
#  'brain',
#  'braintumor',
#  'brainwash',
#  'brand',
#  'brandenburg',
#  'brandon',
#  'brandywineproduct',
#  'brave',
#  'braveri',
#  'brazil',
#  'brazilian',
#  'break',
#  'breakdown',
#  'breakingthefourthwal',
#  'breakup',
#  'breast',
#  'breath',
#  'breed',
#  'brendanfras',
#  'brent',
#  'brettratn',
#  'brew',
#  'brian',
#  'briandepalma',
#  'brianhelgeland',
#  'brianlev',
#  'brianrobbin',
#  'brick',
#  'bride',
#  'bridesmaid',
#  'bridg',
#  'bridge',
#  'brief',
#  'brien',
#  'bright',
#  'brightlightpictur',
#  'brilliant',
#  'bring',
#  'brink',
#  'britain',
#  'british',
#  'britisharmi',
#  'britishbroadcastingcorporation',
#  'britishsecretservic',
#  'broadcast',
#  'broadway',
#  'broke',
#  'broken',
#  'brokenroadproduct',
#  'broker',
#  'bronson',
#  'bronx',
#  'brood',
#  'brook',
#  'brooklyn',
#  'brooklynnewyorkc',
#  'brooks',
#  'broom',
#  'broth',
#  'brothel',
#  'brother',
#  'brotherbrotherrelationship',
#  'brotherhood',
#  'brothers',
#  'brothersisterrelationship',
#  'brought',
#  'brown',
#  'bruce',
#  ...]

# %%
vector[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
vector.shape
# Out:
# (4806, 8000)

# %%
# from numpy import dot
# from numpy.linalg import norm

# def cos_sim(vec):
#     count = 0
#     simvect = []
#     for i in vec:
#         for j in vec:
#             sim = dot(vec[i], vec[j])/(norm(vec[i])*norm(vec[j]))
#             simvect.append(sim)
#     return simvect
# vector = cos_sim(vector)

# %%
# cos_sim(vector)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity.shape
# Out:
# (4806, 4806)

# %%
similarity[0]
# Out:
# array([1.        , 0.07194017, 0.07504692, ..., 0.04007219, 0.        ,
#        0.        ])

# %%
df[df['title'] == 'The Lego Movie'].index[0]
# Out:
# 744

# %%
def recommend(movie,n):
    index = df[df['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:n]:
        print(df.iloc[i[0]].title)

# %%
recommend('Avatar',10)
# Out:
# Aliens vs Predator: Requiem
# Titan A.E.
# Aliens
# Meet Dave
# Independence Day
# Falcon Rising
# Predators
# Jupiter Ascending
# Battle: Los Angeles

# %%
import pickle
pickle.dump(df,open('movielist.pkl','wb'))
pickle.dump(similarity,open('sim.pkl','wb'))

# %%
# !pip install bing-image-downloader
# Out:
# Requirement already satisfied: bing-image-downloader in /home/vivek/.local/lib/python3.8/site-packages (1.1.2)

# %%
movienames = np.array(df.title)

# %%
from bing_image_downloader import downloader as bd
for i in movienames:
    bd.download(i+" Movie", limit=1, output_dir='static/photos', adult_filter_off=False, force_replace=False, timeout=60, verbose=True)
# Out:
# [%] Downloading Images to /home/vivek/Desktop/Recsys/static/photos/Avatar Movie
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.movienewz.com/img/gallery/gone-girl/posters/thumbs/thumbs_gone_girl_movie_ew_cover_1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /home/vivek/Desktop/Recsys/static/photos/Pirates of the Caribbean: At World's End Movie
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.freemovieposters.net/posters/pirates_of_the_caribbean_at_world_s_end_2007_159_poster.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /home/vivek/Desktop/Recsys/static/photos/Spectre Movie
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i0.wp.com/teaser-trailer.com/wp-content/uploads/James-Bond-Spectre-Character-Poster-6.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 1 images.
# [%] Downloading Images to /home/vivek/Desktop/Recsys/static/photos/The Dark Knight Rises Movie
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.